# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
# ```python
# pip install tensorboardX
# ```
# 查看数值 监听曲线

# %% [markdown]
# ## visdom
# from Facebook
# 可以直接获取Tensor（不过实质还是转化为numpy）
# 界面简单，运行效率更高
# ```
# pip install visdom
# ```
# 开启服务
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
from visdom import Visdom
# 创建实例
viz=Visdom()
viz.line([0.],[0.],win='train_loss',opts=dict(title='train_loss'))# win:id标识符   envs：更大的窗口，默认main
viz.line([loss.item()],[global_step],win='train_loss',update='append')
# Out:
# Setting up a new session...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a73682a2fdf> in <module>
#       3 viz=Visdom()
#       4 viz.line([0.],[0.],win='train_loss',opts=dict(title='train_loss'))# win:id标识符   envs：更大的窗口，默认main
# ----> 5 viz.line([loss.item()],[global_step],win='train_loss',update='append')
#
# NameError: name 'loss' is not defined

# %% [markdown]
# 多条线
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
