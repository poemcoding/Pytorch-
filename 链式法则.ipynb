# %% [markdown]
# # 感知机
# ## 多输出

# %%
import torch
from torch.nn import functional as F

# %%
x=torch.randn(1,10)

# %%
w=torch.randn(2,10,requires_grad=True)

# %%
o=torch.sigmoid(x@w.t())

# %%
o.shape
# Out:
# torch.Size([1, 2])

# %%
loss=F.mse_loss(torch.ones(1,2),o)

# %%
loss
# Out:
# tensor(0.5831, grad_fn=<MseLossBackward>)

# %%
loss.backward()

# %%
w.grad
# Out:
# tensor([[ 0.0100, -0.0038,  0.0210, -0.0100, -0.0101, -0.0039,  0.0015,  0.0268,
#           0.0045,  0.0223],
#         [ 0.0717, -0.0273,  0.1503, -0.0716, -0.0721, -0.0278,  0.0107,  0.1921,
#           0.0322,  0.1599]])

# %% [markdown]
# # 链式法则
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# # MLP反向传播
# **链式法则**
# ![image.png](attachment:image.png)
# **多输出感知机求导**

# %% [markdown]
# ![%E5%9B%BE%E7%89%87-2.png](attachment:%E5%9B%BE%E7%89%87-2.png)
#
# ![%E5%9B%BE%E7%89%87-5.png](attachment:%E5%9B%BE%E7%89%87-5.png)
#
# ![%E5%9B%BE%E7%89%87-6.png](attachment:%E5%9B%BE%E7%89%87-6.png)
